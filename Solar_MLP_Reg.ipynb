# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
import torch
from torch import nn, Tensor, optim, cuda
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# # 데이터 불러오기

# %%
# 데이터 로딩
train_X_data = pd.read_csv('./train_set/train_X_data_median.csv', index_col='datetime', parse_dates=True)
test_X_data = pd.read_csv('./test_set/test_X_data_median.csv', index_col='datetime', parse_dates=True)
train_Y_data = pd.read_csv('./train_set/train_Y_data.csv', index_col='datetime', parse_dates=True)
test_Y_data = pd.read_csv('./test_set/test_Y_data.csv', index_col='datetime', parse_dates=True)

test_Y_data_df = test_Y_data

# X 데이터의 모든 열을 숫자형으로 변환
# apply(pd.to_numeric, errors='coerce')를 사용하면 변환되지 않는 값이 NaN으로 변환
train_X_data = train_X_data.apply(pd.to_numeric, errors='coerce') 
test_X_data = test_X_data.apply(pd.to_numeric, errors='coerce')

# 타겟 변수의 'Kp' 열을 숫자형으로 변환
train_Y_data['Kp'] = pd.to_numeric(train_Y_data['Kp'], errors='coerce')
train_Y_data = train_Y_data['Kp'].values.astype(float) # MSELoss를 위해 실수형으로 변환
test_Y_data['Kp'] = pd.to_numeric(test_Y_data['Kp'], errors='coerce')
test_Y_data = test_Y_data['Kp'].values.astype(float) # MSELoss를 위해 실수형으로 변환

# print(train_X_data.head)
# print(train_Y_data.head)

# %% [markdown]
# ### GPU 사용

# %%
if torch.backends.mps.is_available():
    device = 'mps'
    mps_device = torch.device(device)
    torch.cuda.manual_seed_all(777)
    print(device)
else:
    print ("MPS device not found.")

torch.manual_seed(777)
# Out:
# mps

# %% [markdown]
# ### 정규화

# %%
# 데이터 스케일링
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()

# 훈련 데이터에 대해 스케일러 학습 및 변환
train_X_data = scaler_X.fit_transform(train_X_data)
# train_Y_data = scaler_Y.fit_transform(train_Y_data)

# 테스트 데이터에 대해 스케일러 변환
test_X_data = scaler_X.transform(test_X_data)
# test_Y_data = scaler_Y.transform(test_Y_data)

# %% [markdown]
# ### Batch 세팅

# %%
# 데이터 변환 (torch.Tensor로 변환)
train_X_tensor = torch.tensor(train_X_data, dtype=torch.float32)
train_Y_tensor = torch.tensor(train_Y_data, dtype=torch.float32)

# 배치 크기 정의
batch_size = 256

# TensorDataset과 DataLoader를 사용하여 배치 생성
dataset = TensorDataset(train_X_tensor, train_Y_tensor)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### Validation Set

# %%
# 검증 데이터셋 추가
validation_X_data = pd.read_csv('./test_set/test_X_data_MF.csv', index_col='datetime', parse_dates=True)
validation_Y_data = pd.read_csv('./test_set/test_Y_data.csv', index_col='datetime', parse_dates=True)

# X 데이터의 모든 열을 숫자형으로 변환
validation_X_data = validation_X_data.apply(pd.to_numeric, errors='coerce')

# 타겟 변수의 'Kp' 열을 숫자형으로 변환
validation_Y_data['Kp'] = pd.to_numeric(validation_Y_data['Kp'], errors='coerce')
validation_Y_data = validation_Y_data['Kp'].values.astype(float) # MSELoss를 위해 실수형으로 변환

# 검증 데이터 스케일링
validation_X_data = scaler_X.transform(validation_X_data)

# 데이터 변환 (torch.Tensor로 변환)
validation_X_tensor = torch.tensor(validation_X_data, dtype=torch.float32)
validation_Y_tensor = torch.tensor(validation_Y_data, dtype=torch.float32)

# 검증 TensorDataset과 DataLoader를 사용하여 배치 생성
validation_dataset = TensorDataset(validation_X_tensor, validation_Y_tensor)
validation_dataloader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # MLP Model

# %%
class MLPModel(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size, dropout_prob):
        super(MLPModel, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_sizes[0])# 첫 번째 선형 계층 정의
        self.batch_norm1 = nn.BatchNorm1d(hidden_sizes[0])# 첫 번째 배치 정규화 계층  (신경망의 학습을 안정화)
        self.dropout1 = nn.Dropout(dropout_prob)
        self.linear2 = nn.Linear(hidden_sizes[0], hidden_sizes[1])
        self.batch_norm2 = nn.BatchNorm1d(hidden_sizes[1])
        self.dropout2 = nn.Dropout(dropout_prob)
        self.linear3 = nn.Linear(hidden_sizes[1], hidden_sizes[2])
        self.batch_norm3 = nn.BatchNorm1d(hidden_sizes[2])
        self.dropout3 = nn.Dropout(dropout_prob)
        self.linear4 = nn.Linear(hidden_sizes[2], hidden_sizes[3])
        self.batch_norm4 = nn.BatchNorm1d(hidden_sizes[3])
        self.dropout4 = nn.Dropout(dropout_prob)
        self.linear5 = nn.Linear(hidden_sizes[3], output_size)

        self.relu = nn.ReLU()

        # Initialize weights using Xavier uniform initialization
        torch.nn.init.xavier_uniform_(self.linear1.weight)# 첫 번째 선형 계층의 가중치를 Xavier uniform 방식으로 초기화
        torch.nn.init.xavier_uniform_(self.linear2.weight)# gradient vanishing(기울기 소실) 및 gradient exploding(기울기 폭발) 문제를 완화
        torch.nn.init.xavier_uniform_(self.linear3.weight)
        torch.nn.init.xavier_uniform_(self.linear4.weight)
        torch.nn.init.xavier_uniform_(self.linear5.weight)

        # Initialize biases to zero
        nn.init.zeros_(self.linear1.bias)# 첫 번째 선형 계층의 편향을 0으로 초기화
        nn.init.zeros_(self.linear2.bias)
        nn.init.zeros_(self.linear3.bias)
        nn.init.zeros_(self.linear4.bias)
        nn.init.zeros_(self.linear5.bias)

    def forward(self, x):
        x = self.linear1(x) # 첫 번째 선형 변환 적용
        x = self.batch_norm1(x)# 첫 번째 배치 정규화 적용
        x = self.relu(x)# ReLU 활성화 함수 적용
        x = self.dropout1(x)

        x = self.linear2(x)
        x = self.batch_norm2(x)
        x = self.relu(x)
        x = self.dropout2(x)

        x = self.linear3(x)
        x = self.batch_norm3(x)
        x = self.relu(x)
        x = self.dropout3(x)

        x = self.linear4(x)
        x = self.batch_norm4(x)
        x = self.relu(x)
        x = self.dropout4(x)

        x = self.linear5(x)  # No batch norm after the last linear layer
        return x

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self):
       super(WeightedMSELoss, self).__init__()


    def forward(self, predictions, targets):
        sum_targets = targets.sum().item()
        if sum_targets == 0:
            return torch.sqrt(torch.tensor(0.001, dtype=torch.float))
        modified_targets = torch.where(targets == 0, torch.tensor(0.8, dtype=targets.dtype), targets)
        weights = modified_targets / sum_targets
        loss = (weights * (predictions - targets).pow(2)).sum()
        return torch.sqrt(loss)

# %%
# 모델 초기화
input_size = train_X_data.shape[1]   # input data feature 수, X_train의 열 수
hidden_sizes = [800, 800, 800, 800]
output_size = 1   # output data feature 수, 회귀 문제이므로 출력 크기는 1
dropout_prob=0.8
model = MLPModel(input_size, hidden_sizes, output_size, dropout_prob).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
#criterion = nn.MSELoss()
criterion = WeightedMSELoss()
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# %% [markdown]
# ### Train

# %%
def train_and_validate(train_dataloader, validation_dataloader, model, optimizer, criterion, num_epochs=500):
    total_train_batch = len(train_dataloader)
    total_validation_batch = len(validation_dataloader)
    model.train()
    train_loss_list = []  # 학습 손실을 저장할 리스트
    validation_loss_list = []  # 검증 손실을 저장할 리스트

    for epoch in range(num_epochs):
        model.train()  # 모델을 학습 모드로 설정
        avg_train_cost = 0

        for X, Y in train_dataloader:
            optimizer.zero_grad()
            X, Y = X.to(device), Y.to(device)

            prediction = model(X).squeeze()
            loss = criterion(prediction, Y)

            loss.backward()
            optimizer.step()

            avg_train_cost += loss / total_train_batch

        train_loss_list.append(avg_train_cost.item())  # 현재 학습 손실을 리스트에 저장

        # 검증 손실 계산
        model.eval()  # 모델을 평가 모드로 설정
        avg_validation_cost = 0

        with torch.no_grad():
            for X_val, Y_val in validation_dataloader:
                X_val, Y_val = X_val.to(device), Y_val.to(device)
                val_prediction = model(X_val).squeeze()
                val_loss = criterion(val_prediction, Y_val)
                avg_validation_cost += val_loss / total_validation_batch

        validation_loss_list.append(avg_validation_cost.item())  # 현재 검증 손실을 리스트에 저장

        print(f'Epoch: {epoch + 1}, Training Loss = {avg_train_cost:.9f}, Validation Loss = {avg_validation_cost:.9f}')

    return train_loss_list, validation_loss_list  # 학습 및 검증 손실 리스트 반환

# %%
train_loss_list, validation_loss_list = train_and_validate(dataloader, validation_dataloader, model, optimizer, criterion)
# Out:
# Epoch: 1, Training Loss = 2.308062792, Validation Loss = 1.755524635
# Epoch: 2, Training Loss = 1.364828110, Validation Loss = 1.337607026
# Epoch: 3, Training Loss = 1.137177587, Validation Loss = 1.044668198
# Epoch: 4, Training Loss = 1.075161099, Validation Loss = 0.955951691
# Epoch: 5, Training Loss = 1.050359607, Validation Loss = 0.898791194
# Epoch: 6, Training Loss = 1.033334374, Validation Loss = 0.903119862
# Epoch: 7, Training Loss = 1.019837499, Validation Loss = 0.882857978
# Epoch: 8, Training Loss = 1.012979865, Validation Loss = 0.860184193
# Epoch: 9, Training Loss = 0.993009984, Validation Loss = 0.835114419
# Epoch: 10, Training Loss = 0.999078214, Validation Loss = 0.854561746
# Epoch: 11, Training Loss = 0.988041878, Validation Loss = 0.828241706
# Epoch: 12, Training Loss = 0.988748074, Validation Loss = 0.814279735
# Epoch: 13, Training Loss = 0.987209022, Validation Loss = 0.801368117
# Epoch: 14, Training Loss = 0.980801463, Validation Loss = 0.791192591
# Epoch: 15, Training Loss = 0.978328407, Validation Loss = 0.771106780
# Epoch: 16, Training Loss = 0.970348954, Validation Loss = 0.757942438
# Epoch: 17, Training Loss = 0.960280597, Validation Loss = 0.766531587
# Epoch: 18, Training Loss = 0.968292654, Validation Loss = 0.763858974
# Epoch: 19, Training Loss = 0.964593828, Validation Loss = 0.749307752
# Epoch: 20, Training Loss = 0.963115036, Validation Loss = 0.747841001
# Epoch: 21, Training Loss = 0.951693177, Validation Loss = 0.747198582
# Epoch: 22, Training Loss = 0.953996718, Validation Loss = 0.768515944
# Epoch: 23, Training Loss = 0.947935402, Validation Loss = 0.748178005
# Epoch: 24, Training Loss = 0.942802131, Validation Loss = 0.744566679
# Epoch: 25, Training Loss = 0.946185470, Validation Loss = 0.754993618
# Epoch: 26, Training Loss = 0.936044931, Validation Loss = 0.748118877
# Epoch: 27, Training Loss = 0.939348757, Validation Loss = 0.753334939
# Epoch: 28, Training Loss = 0.933797777, Validation Loss = 0.743856132
# Epoch: 29, Training Loss = 0.940276086, Validation Loss = 0.742631674
# Epoch: 30, Training Loss = 0.941018939, Validation Loss = 0.740380585
# Epoch: 31, Training Loss = 0.932025433, Validation Loss = 0.767844677
# Epoch: 32, Training Loss = 0.928729236, Validation Loss = 0.746465087
# Epoch: 33, Training Loss = 0.931050658, Validation Loss = 0.782319307
# Epoch: 34, Training Loss = 0.930004656, Validation Loss = 0.740181446
# Epoch: 35, Training Loss = 0.924383283, Validation Loss = 0.736563563
# Epoch: 36, Training Loss = 0.929548323, Validation Loss = 0.745734096
# Epoch: 37, Training Loss = 0.922171652, Validation Loss = 0.754376769
# Epoch: 38, Training Loss = 0.923929095, Validation Loss = 0.743690789
# Epoch: 39, Training Loss = 0.923699439, Validation Loss = 0.745799243
# Epoch: 40, Training Loss = 0.920109272, Validation Loss = 0.736923575
# Epoch: 41, Training Loss = 0.925193489, Validation Loss = 0.753535450
# Epoch: 42, Training Loss = 0.919962645, Validation Loss = 0.760286093
# Epoch: 43, Training Loss = 0.928441286, Validation Loss = 0.769323230
# Epoch: 44, Training Loss = 0.920531511, Validation Loss = 0.759076834
# Epoch: 45, Training Loss = 0.923211098, Validation Loss = 0.752819121
# Epoch: 46, Training Loss = 0.918084681, Validation Loss = 0.757126749
# Epoch: 47, Training Loss = 0.911327183, Validation Loss = 0.763820827
# Epoch: 48, Training Loss = 0.920372128, Validation Loss = 0.756504297
# Epoch: 49, Training Loss = 0.914558411, Validation Loss = 0.756173909
# Epoch: 50, Training Loss = 0.908623695, Validation Loss = 0.742050707
# Epoch: 51, Training Loss = 0.910727024, Validation Loss = 0.747983098
# Epoch: 52, Training Loss = 0.906583607, Validation Loss = 0.756929874
# Epoch: 53, Training Loss = 0.910560131, Validation Loss = 0.771188676
# Epoch: 54, Training Loss = 0.906973481, Validation Loss = 0.743475318
# Epoch: 55, Training Loss = 0.902475655, Validation Loss = 0.750057757
# Epoch: 56, Training Loss = 0.905225337, Validation Loss = 0.745938301
# Epoch: 57, Training Loss = 0.909876466, Validation Loss = 0.757332921
# Epoch: 58, Training Loss = 0.905370951, Validation Loss = 0.788090408
# Epoch: 59, Training Loss = 0.897395253, Validation Loss = 0.764494538
# Epoch: 60, Training Loss = 0.904720902, Validation Loss = 0.772841811
# Epoch: 61, Training Loss = 0.901420653, Validation Loss = 0.740815103
# Epoch: 62, Training Loss = 0.911535025, Validation Loss = 0.776165307
# Epoch: 63, Training Loss = 0.903117657, Validation Loss = 0.764837563
# Epoch: 64, Training Loss = 0.902754366, Validation Loss = 0.751563013
# Epoch: 65, Training Loss = 0.899884522, Validation Loss = 0.747592330
# Epoch: 66, Training Loss = 0.901811123, Validation Loss = 0.748933911
# Epoch: 67, Training Loss = 0.902975798, Validation Loss = 0.736264408
# Epoch: 68, Training Loss = 0.897779763, Validation Loss = 0.756645501
# Epoch: 69, Training Loss = 0.904527366, Validation Loss = 0.750608087
# Epoch: 70, Training Loss = 0.901570737, Validation Loss = 0.753310084
# Epoch: 71, Training Loss = 0.899860024, Validation Loss = 0.750951350
# Epoch: 72, Training Loss = 0.892758906, Validation Loss = 0.758786440
# Epoch: 73, Training Loss = 0.894201934, Validation Loss = 0.743068278
# Epoch: 74, Training Loss = 0.897466898, Validation Loss = 0.762985945
# Epoch: 75, Training Loss = 0.893973649, Validation Loss = 0.761699557
# Epoch: 76, Training Loss = 0.892210782, Validation Loss = 0.759294987
# Epoch: 77, Training Loss = 0.895272613, Validation Loss = 0.745624185
# Epoch: 78, Training Loss = 0.889660597, Validation Loss = 0.754075885
# Epoch: 79, Training Loss = 0.890246511, Validation Loss = 0.765378892
# Epoch: 80, Training Loss = 0.895413637, Validation Loss = 0.760987937
# Epoch: 81, Training Loss = 0.892730772, Validation Loss = 0.742177248
# Epoch: 82, Training Loss = 0.894004047, Validation Loss = 0.752345562
# Epoch: 83, Training Loss = 0.894541442, Validation Loss = 0.741757631
# Epoch: 84, Training Loss = 0.890012503, Validation Loss = 0.754021049
# Epoch: 85, Training Loss = 0.892686605, Validation Loss = 0.753264904
# Epoch: 86, Training Loss = 0.893405259, Validation Loss = 0.758375406
# Epoch: 87, Training Loss = 0.890192270, Validation Loss = 0.766101956
# Epoch: 88, Training Loss = 0.890232146, Validation Loss = 0.755656481
# Epoch: 89, Training Loss = 0.896009922, Validation Loss = 0.771926999
# Epoch: 90, Training Loss = 0.894744694, Validation Loss = 0.749796748
# Epoch: 91, Training Loss = 0.893017590, Validation Loss = 0.745492637
# Epoch: 92, Training Loss = 0.894634426, Validation Loss = 0.747181475
# Epoch: 93, Training Loss = 0.899064064, Validation Loss = 0.749145031
# Epoch: 94, Training Loss = 0.891653836, Validation Loss = 0.766925335
# Epoch: 95, Training Loss = 0.887049615, Validation Loss = 0.764212132
# Epoch: 96, Training Loss = 0.887236297, Validation Loss = 0.747558713
# Epoch: 97, Training Loss = 0.892945111, Validation Loss = 0.753553450
# Epoch: 98, Training Loss = 0.890813828, Validation Loss = 0.735147357
# Epoch: 99, Training Loss = 0.891918600, Validation Loss = 0.772579789
# Epoch: 100, Training Loss = 0.888422906, Validation Loss = 0.747716248
# Epoch: 101, Training Loss = 0.886636138, Validation Loss = 0.758532643
# Epoch: 102, Training Loss = 0.883753181, Validation Loss = 0.736870766
# Epoch: 103, Training Loss = 0.891528070, Validation Loss = 0.745884597
# Epoch: 104, Training Loss = 0.886738241, Validation Loss = 0.765813529
# Epoch: 105, Training Loss = 0.886934996, Validation Loss = 0.753873348
# Epoch: 106, Training Loss = 0.884500563, Validation Loss = 0.773434222
# Epoch: 107, Training Loss = 0.883916795, Validation Loss = 0.748594344
# Epoch: 108, Training Loss = 0.886874139, Validation Loss = 0.763296485
# Epoch: 109, Training Loss = 0.888268292, Validation Loss = 0.753017128
# Epoch: 110, Training Loss = 0.885539055, Validation Loss = 0.756479800
# Epoch: 111, Training Loss = 0.887541711, Validation Loss = 0.751129091
# Epoch: 112, Training Loss = 0.882651746, Validation Loss = 0.756423950
# Epoch: 113, Training Loss = 0.883008301, Validation Loss = 0.750198066
# Epoch: 114, Training Loss = 0.882951081, Validation Loss = 0.760141969
# Epoch: 115, Training Loss = 0.881063044, Validation Loss = 0.747605860
# Epoch: 116, Training Loss = 0.886270940, Validation Loss = 0.767894804
# Epoch: 117, Training Loss = 0.884111822, Validation Loss = 0.766575873
# Epoch: 118, Training Loss = 0.883078635, Validation Loss = 0.768995404
# Epoch: 119, Training Loss = 0.880623817, Validation Loss = 0.758319855
# Epoch: 120, Training Loss = 0.880871713, Validation Loss = 0.754078627
# Epoch: 121, Training Loss = 0.880853772, Validation Loss = 0.773556054
# Epoch: 122, Training Loss = 0.878977895, Validation Loss = 0.750711262
# Epoch: 123, Training Loss = 0.880734503, Validation Loss = 0.742878318
# Epoch: 124, Training Loss = 0.883167565, Validation Loss = 0.757910073
# Epoch: 125, Training Loss = 0.880373180, Validation Loss = 0.743955076
# Epoch: 126, Training Loss = 0.888264298, Validation Loss = 0.765152454
# Epoch: 127, Training Loss = 0.884474099, Validation Loss = 0.776520312
# Epoch: 128, Training Loss = 0.879937410, Validation Loss = 0.759439349
# Epoch: 129, Training Loss = 0.883704364, Validation Loss = 0.786490381
# Epoch: 130, Training Loss = 0.883916676, Validation Loss = 0.771617889
# Epoch: 131, Training Loss = 0.877671361, Validation Loss = 0.757095456
# Epoch: 132, Training Loss = 0.883907080, Validation Loss = 0.768782556
# Epoch: 133, Training Loss = 0.878693283, Validation Loss = 0.771215320
# Epoch: 134, Training Loss = 0.877894759, Validation Loss = 0.742097974
# Epoch: 135, Training Loss = 0.874064744, Validation Loss = 0.759531140
# Epoch: 136, Training Loss = 0.874891758, Validation Loss = 0.750356853
# Epoch: 137, Training Loss = 0.880399406, Validation Loss = 0.769471288
# Epoch: 138, Training Loss = 0.876058817, Validation Loss = 0.769632101
# Epoch: 139, Training Loss = 0.875914395, Validation Loss = 0.768036604
# Epoch: 140, Training Loss = 0.879725397, Validation Loss = 0.750797093
# Epoch: 141, Training Loss = 0.883438587, Validation Loss = 0.751433313
# Epoch: 142, Training Loss = 0.882944703, Validation Loss = 0.746621370
# Epoch: 143, Training Loss = 0.876425564, Validation Loss = 0.770503879
# Epoch: 144, Training Loss = 0.876651704, Validation Loss = 0.748420715
# Epoch: 145, Training Loss = 0.878738225, Validation Loss = 0.770297527
# Epoch: 146, Training Loss = 0.880137980, Validation Loss = 0.758111298
# Epoch: 147, Training Loss = 0.875068724, Validation Loss = 0.759636998
# Epoch: 148, Training Loss = 0.876665473, Validation Loss = 0.755066097
# Epoch: 149, Training Loss = 0.877512872, Validation Loss = 0.757009506
# Epoch: 150, Training Loss = 0.877143264, Validation Loss = 0.766025543
# Epoch: 151, Training Loss = 0.875094891, Validation Loss = 0.765112102
# Epoch: 152, Training Loss = 0.878920734, Validation Loss = 0.768199980
# Epoch: 153, Training Loss = 0.880572140, Validation Loss = 0.762690067
# Epoch: 154, Training Loss = 0.871800125, Validation Loss = 0.758141100
# Epoch: 155, Training Loss = 0.876183093, Validation Loss = 0.752641559
# Epoch: 156, Training Loss = 0.882673621, Validation Loss = 0.769134521
# Epoch: 157, Training Loss = 0.882618964, Validation Loss = 0.772664070
# Epoch: 158, Training Loss = 0.877419949, Validation Loss = 0.746942222
# Epoch: 159, Training Loss = 0.880605936, Validation Loss = 0.752416193
# Epoch: 160, Training Loss = 0.876377881, Validation Loss = 0.743342280
# Epoch: 161, Training Loss = 0.877530515, Validation Loss = 0.754208803
# Epoch: 162, Training Loss = 0.872208953, Validation Loss = 0.763671279
# Epoch: 163, Training Loss = 0.876994193, Validation Loss = 0.746143341
# Epoch: 164, Training Loss = 0.873967111, Validation Loss = 0.755971491
# Epoch: 165, Training Loss = 0.876648068, Validation Loss = 0.750079989
# Epoch: 166, Training Loss = 0.869619608, Validation Loss = 0.770209491
# Epoch: 167, Training Loss = 0.875300527, Validation Loss = 0.761559486
# Epoch: 168, Training Loss = 0.881094694, Validation Loss = 0.753109336
# Epoch: 169, Training Loss = 0.874262571, Validation Loss = 0.755863726
# Epoch: 170, Training Loss = 0.873471498, Validation Loss = 0.752184629
# Epoch: 171, Training Loss = 0.878685951, Validation Loss = 0.756121159
# Epoch: 172, Training Loss = 0.875264645, Validation Loss = 0.760945916
# Epoch: 173, Training Loss = 0.872974217, Validation Loss = 0.754571140
# Epoch: 174, Training Loss = 0.873289585, Validation Loss = 0.761893153
# Epoch: 175, Training Loss = 0.871838629, Validation Loss = 0.744388700
# Epoch: 176, Training Loss = 0.872142434, Validation Loss = 0.753936768
# Epoch: 177, Training Loss = 0.871576190, Validation Loss = 0.761919439
# Epoch: 178, Training Loss = 0.872750342, Validation Loss = 0.767246664
# Epoch: 179, Training Loss = 0.870285869, Validation Loss = 0.778644323
# Epoch: 180, Training Loss = 0.872675240, Validation Loss = 0.754292011
# Epoch: 181, Training Loss = 0.875586450, Validation Loss = 0.754891515
# Epoch: 182, Training Loss = 0.871464789, Validation Loss = 0.752499342
# Epoch: 183, Training Loss = 0.873809934, Validation Loss = 0.759693921
# Epoch: 184, Training Loss = 0.873202026, Validation Loss = 0.770150542
# Epoch: 185, Training Loss = 0.872318029, Validation Loss = 0.760528743
# Epoch: 186, Training Loss = 0.874573767, Validation Loss = 0.769930243
# Epoch: 187, Training Loss = 0.873740971, Validation Loss = 0.763903618
# Epoch: 188, Training Loss = 0.873417675, Validation Loss = 0.772457719
# Epoch: 189, Training Loss = 0.871735811, Validation Loss = 0.756296992
# Epoch: 190, Training Loss = 0.871684194, Validation Loss = 0.767347455
# Epoch: 191, Training Loss = 0.873155713, Validation Loss = 0.762898445
# Epoch: 192, Training Loss = 0.869144022, Validation Loss = 0.762313485
# Epoch: 193, Training Loss = 0.873791218, Validation Loss = 0.749243140
# Epoch: 194, Training Loss = 0.874062657, Validation Loss = 0.759616613
# Epoch: 195, Training Loss = 0.872891366, Validation Loss = 0.748570681
# Epoch: 196, Training Loss = 0.873100758, Validation Loss = 0.761740685
# Epoch: 197, Training Loss = 0.872736633, Validation Loss = 0.771535456
# Epoch: 198, Training Loss = 0.874866545, Validation Loss = 0.770039320
# Epoch: 199, Training Loss = 0.873078465, Validation Loss = 0.747096002
# Epoch: 200, Training Loss = 0.870942771, Validation Loss = 0.753385007
# Epoch: 201, Training Loss = 0.868463039, Validation Loss = 0.770424128
# Epoch: 202, Training Loss = 0.874888480, Validation Loss = 0.761493266
# Epoch: 203, Training Loss = 0.869485021, Validation Loss = 0.754042447
# Epoch: 204, Training Loss = 0.869529843, Validation Loss = 0.762727320
# Epoch: 205, Training Loss = 0.869904876, Validation Loss = 0.752210796
# Epoch: 206, Training Loss = 0.876990139, Validation Loss = 0.757846713
# Epoch: 207, Training Loss = 0.872834206, Validation Loss = 0.750566125
# Epoch: 208, Training Loss = 0.872815073, Validation Loss = 0.746377528
# Epoch: 209, Training Loss = 0.869271994, Validation Loss = 0.760943234
# Epoch: 210, Training Loss = 0.872548163, Validation Loss = 0.758139133
# Epoch: 211, Training Loss = 0.874499321, Validation Loss = 0.754725933
# Epoch: 212, Training Loss = 0.872826397, Validation Loss = 0.758360326
# Epoch: 213, Training Loss = 0.867977202, Validation Loss = 0.765705109
# Epoch: 214, Training Loss = 0.873606324, Validation Loss = 0.758153558
# Epoch: 215, Training Loss = 0.870018899, Validation Loss = 0.757770956
# Epoch: 216, Training Loss = 0.869792223, Validation Loss = 0.744411707
# Epoch: 217, Training Loss = 0.873717308, Validation Loss = 0.774335623
# Epoch: 218, Training Loss = 0.868841231, Validation Loss = 0.774968088
# Epoch: 219, Training Loss = 0.870684028, Validation Loss = 0.752530396
# Epoch: 220, Training Loss = 0.867488921, Validation Loss = 0.765983641
# Epoch: 221, Training Loss = 0.867854059, Validation Loss = 0.760384560
# Epoch: 222, Training Loss = 0.872415245, Validation Loss = 0.759682715
# Epoch: 223, Training Loss = 0.865202487, Validation Loss = 0.748907208
# Epoch: 224, Training Loss = 0.871166825, Validation Loss = 0.765439212
# Epoch: 225, Training Loss = 0.867599547, Validation Loss = 0.756508708
# Epoch: 226, Training Loss = 0.870308995, Validation Loss = 0.758103490
# Epoch: 227, Training Loss = 0.868848085, Validation Loss = 0.762133598
# Epoch: 228, Training Loss = 0.867362559, Validation Loss = 0.754194021
# Epoch: 229, Training Loss = 0.871899307, Validation Loss = 0.752140880
# Epoch: 230, Training Loss = 0.868519485, Validation Loss = 0.761225104
# Epoch: 231, Training Loss = 0.867179394, Validation Loss = 0.770939410
# Epoch: 232, Training Loss = 0.875012457, Validation Loss = 0.768835068
# Epoch: 233, Training Loss = 0.867525697, Validation Loss = 0.750954092
# Epoch: 234, Training Loss = 0.870950639, Validation Loss = 0.759461761
# Epoch: 235, Training Loss = 0.868546188, Validation Loss = 0.753240883
# Epoch: 236, Training Loss = 0.865743637, Validation Loss = 0.745658517
# Epoch: 237, Training Loss = 0.865398705, Validation Loss = 0.759489298
# Epoch: 238, Training Loss = 0.865690053, Validation Loss = 0.763646483
# Epoch: 239, Training Loss = 0.866323829, Validation Loss = 0.767691016
# Epoch: 240, Training Loss = 0.870689988, Validation Loss = 0.748759985
# Epoch: 241, Training Loss = 0.864996552, Validation Loss = 0.755898476
# Epoch: 242, Training Loss = 0.867504358, Validation Loss = 0.761887550
# Epoch: 243, Training Loss = 0.868857324, Validation Loss = 0.757171988
# Epoch: 244, Training Loss = 0.867995679, Validation Loss = 0.777513087
# Epoch: 245, Training Loss = 0.867114723, Validation Loss = 0.755609453
# Epoch: 246, Training Loss = 0.864747822, Validation Loss = 0.759765148
# Epoch: 247, Training Loss = 0.868964612, Validation Loss = 0.754717350
# Epoch: 248, Training Loss = 0.866809905, Validation Loss = 0.752275586
# Epoch: 249, Training Loss = 0.868650258, Validation Loss = 0.771068752
# Epoch: 250, Training Loss = 0.865996182, Validation Loss = 0.763539135
# Epoch: 251, Training Loss = 0.866624057, Validation Loss = 0.765118897
# Epoch: 252, Training Loss = 0.866856575, Validation Loss = 0.757916749
# Epoch: 253, Training Loss = 0.864145935, Validation Loss = 0.747348189
# Epoch: 254, Training Loss = 0.870756507, Validation Loss = 0.750448465
# Epoch: 255, Training Loss = 0.864470303, Validation Loss = 0.757851422
# Epoch: 256, Training Loss = 0.868470192, Validation Loss = 0.777012408
# Epoch: 257, Training Loss = 0.866176307, Validation Loss = 0.763673127
# Epoch: 258, Training Loss = 0.869382322, Validation Loss = 0.766136765
# Epoch: 259, Training Loss = 0.867079139, Validation Loss = 0.748595119
# Epoch: 260, Training Loss = 0.867458701, Validation Loss = 0.762667775
# Epoch: 261, Training Loss = 0.867142498, Validation Loss = 0.753872931
# Epoch: 262, Training Loss = 0.865126193, Validation Loss = 0.770024061
# Epoch: 263, Training Loss = 0.871694148, Validation Loss = 0.757048786
# Epoch: 264, Training Loss = 0.866553187, Validation Loss = 0.748638332
# Epoch: 265, Training Loss = 0.869253159, Validation Loss = 0.777101815
# Epoch: 266, Training Loss = 0.867187321, Validation Loss = 0.753947794
# Epoch: 267, Training Loss = 0.870702028, Validation Loss = 0.752797425
# Epoch: 268, Training Loss = 0.866358340, Validation Loss = 0.758568347
# Epoch: 269, Training Loss = 0.871627092, Validation Loss = 0.755559981
# Epoch: 270, Training Loss = 0.865566075, Validation Loss = 0.749633968
# Epoch: 271, Training Loss = 0.867790341, Validation Loss = 0.752888560
# Epoch: 272, Training Loss = 0.865845740, Validation Loss = 0.754267931
# Epoch: 273, Training Loss = 0.866247892, Validation Loss = 0.765697837
# Epoch: 274, Training Loss = 0.867260456, Validation Loss = 0.759626269
# Epoch: 275, Training Loss = 0.860032678, Validation Loss = 0.759603739
# Epoch: 276, Training Loss = 0.862353206, Validation Loss = 0.761615872
# Epoch: 277, Training Loss = 0.868342996, Validation Loss = 0.761530221
# Epoch: 278, Training Loss = 0.861957192, Validation Loss = 0.750565827
# Epoch: 279, Training Loss = 0.868457913, Validation Loss = 0.755381823
# Epoch: 280, Training Loss = 0.867643237, Validation Loss = 0.746279180
# Epoch: 281, Training Loss = 0.865330756, Validation Loss = 0.755160570
# Epoch: 282, Training Loss = 0.864409864, Validation Loss = 0.757325292
# Epoch: 283, Training Loss = 0.869342029, Validation Loss = 0.778395534
# Epoch: 284, Training Loss = 0.869506001, Validation Loss = 0.762952924
# Epoch: 285, Training Loss = 0.861365616, Validation Loss = 0.761252403
# Epoch: 286, Training Loss = 0.863312423, Validation Loss = 0.769385576
# Epoch: 287, Training Loss = 0.863313079, Validation Loss = 0.771813571
# Epoch: 288, Training Loss = 0.861914694, Validation Loss = 0.743495464
# Epoch: 289, Training Loss = 0.864281356, Validation Loss = 0.762113392
# Epoch: 290, Training Loss = 0.868487895, Validation Loss = 0.760097265
# Epoch: 291, Training Loss = 0.863182068, Validation Loss = 0.759581506
# Epoch: 292, Training Loss = 0.864568770, Validation Loss = 0.753073692
# Epoch: 293, Training Loss = 0.868234515, Validation Loss = 0.761001587
# Epoch: 294, Training Loss = 0.863811135, Validation Loss = 0.758376360
# Epoch: 295, Training Loss = 0.864913642, Validation Loss = 0.768790722
# Epoch: 296, Training Loss = 0.860290706, Validation Loss = 0.773198426
# Epoch: 297, Training Loss = 0.864564836, Validation Loss = 0.760628879
# Epoch: 298, Training Loss = 0.868448615, Validation Loss = 0.757532001
# Epoch: 299, Training Loss = 0.868944883, Validation Loss = 0.775290668
# Epoch: 300, Training Loss = 0.860778928, Validation Loss = 0.767333984
# Epoch: 301, Training Loss = 0.862543762, Validation Loss = 0.768949330
# Epoch: 302, Training Loss = 0.863365948, Validation Loss = 0.773305297
# Epoch: 303, Training Loss = 0.864367545, Validation Loss = 0.753592968
# Epoch: 304, Training Loss = 0.863188565, Validation Loss = 0.756428957
# Epoch: 305, Training Loss = 0.869057000, Validation Loss = 0.756914556
# Epoch: 306, Training Loss = 0.863135219, Validation Loss = 0.762256622
# Epoch: 307, Training Loss = 0.863598645, Validation Loss = 0.759282351
# Epoch: 308, Training Loss = 0.860626698, Validation Loss = 0.755787015
# Epoch: 309, Training Loss = 0.864277184, Validation Loss = 0.747972369
# Epoch: 310, Training Loss = 0.860895753, Validation Loss = 0.758755028
# Epoch: 311, Training Loss = 0.863154709, Validation Loss = 0.762674809
# Epoch: 312, Training Loss = 0.863917291, Validation Loss = 0.746547759
# Epoch: 313, Training Loss = 0.862541974, Validation Loss = 0.758415222
# Epoch: 314, Training Loss = 0.866676331, Validation Loss = 0.760565579
# Epoch: 315, Training Loss = 0.865968049, Validation Loss = 0.750307441
# Epoch: 316, Training Loss = 0.857830405, Validation Loss = 0.751810968
# Epoch: 317, Training Loss = 0.866165817, Validation Loss = 0.754365504
# Epoch: 318, Training Loss = 0.863688648, Validation Loss = 0.755036056
# Epoch: 319, Training Loss = 0.861936986, Validation Loss = 0.761389732
# Epoch: 320, Training Loss = 0.867967486, Validation Loss = 0.767940521
# Epoch: 321, Training Loss = 0.863491535, Validation Loss = 0.759832382
# Epoch: 322, Training Loss = 0.867175639, Validation Loss = 0.761814654
# Epoch: 323, Training Loss = 0.863162518, Validation Loss = 0.759796739
# Epoch: 324, Training Loss = 0.866858065, Validation Loss = 0.764938354
# Epoch: 325, Training Loss = 0.861868441, Validation Loss = 0.762228668
# Epoch: 326, Training Loss = 0.865348577, Validation Loss = 0.764469981
# Epoch: 327, Training Loss = 0.869764328, Validation Loss = 0.748067200
# Epoch: 328, Training Loss = 0.861531496, Validation Loss = 0.765776575
# Epoch: 329, Training Loss = 0.864279985, Validation Loss = 0.759326458
# Epoch: 330, Training Loss = 0.864459932, Validation Loss = 0.768033266
# Epoch: 331, Training Loss = 0.862063348, Validation Loss = 0.763422847
# Epoch: 332, Training Loss = 0.861388922, Validation Loss = 0.755270600
# Epoch: 333, Training Loss = 0.860449314, Validation Loss = 0.774782360
# Epoch: 334, Training Loss = 0.866209865, Validation Loss = 0.769757450
# Epoch: 335, Training Loss = 0.861946821, Validation Loss = 0.755713940
# Epoch: 336, Training Loss = 0.861611784, Validation Loss = 0.744580746
# Epoch: 337, Training Loss = 0.863403618, Validation Loss = 0.760909796
# Epoch: 338, Training Loss = 0.862758398, Validation Loss = 0.755758703
# Epoch: 339, Training Loss = 0.865027308, Validation Loss = 0.748952448
# Epoch: 340, Training Loss = 0.864048302, Validation Loss = 0.772753537
# Epoch: 341, Training Loss = 0.863067806, Validation Loss = 0.765889525
# Epoch: 342, Training Loss = 0.863917649, Validation Loss = 0.755989254
# Epoch: 343, Training Loss = 0.860618830, Validation Loss = 0.749165535
# Epoch: 344, Training Loss = 0.863760054, Validation Loss = 0.758846045
# Epoch: 345, Training Loss = 0.864024580, Validation Loss = 0.754327834
# Epoch: 346, Training Loss = 0.864105403, Validation Loss = 0.761734962
# Epoch: 347, Training Loss = 0.861519516, Validation Loss = 0.766352117
# Epoch: 348, Training Loss = 0.860118091, Validation Loss = 0.762290120
# Epoch: 349, Training Loss = 0.862496674, Validation Loss = 0.767131090
# Epoch: 350, Training Loss = 0.865887702, Validation Loss = 0.774883270
# Epoch: 351, Training Loss = 0.864715517, Validation Loss = 0.765806556
# Epoch: 352, Training Loss = 0.865639269, Validation Loss = 0.757164180
# Epoch: 353, Training Loss = 0.862176955, Validation Loss = 0.770572126
# Epoch: 354, Training Loss = 0.861839950, Validation Loss = 0.768941164
# Epoch: 355, Training Loss = 0.857668638, Validation Loss = 0.768045962
# Epoch: 356, Training Loss = 0.864271224, Validation Loss = 0.759904265
# Epoch: 357, Training Loss = 0.861728132, Validation Loss = 0.754381537
# Epoch: 358, Training Loss = 0.862084448, Validation Loss = 0.771851838
# Epoch: 359, Training Loss = 0.857245862, Validation Loss = 0.765186369
# Epoch: 360, Training Loss = 0.863429666, Validation Loss = 0.753150642
# Epoch: 361, Training Loss = 0.863127589, Validation Loss = 0.763760090
# Epoch: 362, Training Loss = 0.861771286, Validation Loss = 0.760368168
# Epoch: 363, Training Loss = 0.860594869, Validation Loss = 0.749423206
# Epoch: 364, Training Loss = 0.862810731, Validation Loss = 0.752503037
# Epoch: 365, Training Loss = 0.861316383, Validation Loss = 0.763537824
# Epoch: 366, Training Loss = 0.862277269, Validation Loss = 0.755036533
# Epoch: 367, Training Loss = 0.860806286, Validation Loss = 0.749900281
# Epoch: 368, Training Loss = 0.856643558, Validation Loss = 0.765057921
# Epoch: 369, Training Loss = 0.863793552, Validation Loss = 0.756571710
# Epoch: 370, Training Loss = 0.860877872, Validation Loss = 0.763924837
# Epoch: 371, Training Loss = 0.861423731, Validation Loss = 0.755913615
# Epoch: 372, Training Loss = 0.860748589, Validation Loss = 0.751665115
# Epoch: 373, Training Loss = 0.860249817, Validation Loss = 0.760979295
# Epoch: 374, Training Loss = 0.860253811, Validation Loss = 0.766591191
# Epoch: 375, Training Loss = 0.859486878, Validation Loss = 0.767600060
# Epoch: 376, Training Loss = 0.864202917, Validation Loss = 0.765750349
# Epoch: 377, Training Loss = 0.864013970, Validation Loss = 0.758763909
# Epoch: 378, Training Loss = 0.861870170, Validation Loss = 0.754499078
# Epoch: 379, Training Loss = 0.857903004, Validation Loss = 0.788226008
# Epoch: 380, Training Loss = 0.858331263, Validation Loss = 0.756716728
# Epoch: 381, Training Loss = 0.861890137, Validation Loss = 0.757628262
# Epoch: 382, Training Loss = 0.860839009, Validation Loss = 0.766521871
# Epoch: 383, Training Loss = 0.866681039, Validation Loss = 0.765021384
# Epoch: 384, Training Loss = 0.861337483, Validation Loss = 0.768568516
# Epoch: 385, Training Loss = 0.858942807, Validation Loss = 0.770663321
# Epoch: 386, Training Loss = 0.862637162, Validation Loss = 0.762086809
# Epoch: 387, Training Loss = 0.859564066, Validation Loss = 0.761350274
# Epoch: 388, Training Loss = 0.864227295, Validation Loss = 0.756522775
# Epoch: 389, Training Loss = 0.861187696, Validation Loss = 0.758572459
# Epoch: 390, Training Loss = 0.858664513, Validation Loss = 0.754358053
# Epoch: 391, Training Loss = 0.862092555, Validation Loss = 0.762826085
# Epoch: 392, Training Loss = 0.857144952, Validation Loss = 0.765128970
# Epoch: 393, Training Loss = 0.856816471, Validation Loss = 0.759321868
# Epoch: 394, Training Loss = 0.864091396, Validation Loss = 0.748906016
# Epoch: 395, Training Loss = 0.860940158, Validation Loss = 0.761035979
# Epoch: 396, Training Loss = 0.862250030, Validation Loss = 0.756873548
# Epoch: 397, Training Loss = 0.858079731, Validation Loss = 0.759321392
# Epoch: 398, Training Loss = 0.858207285, Validation Loss = 0.767276585
# Epoch: 399, Training Loss = 0.862074554, Validation Loss = 0.757477999
# Epoch: 400, Training Loss = 0.857263386, Validation Loss = 0.753309369
# Epoch: 401, Training Loss = 0.861279607, Validation Loss = 0.744304001
# Epoch: 402, Training Loss = 0.860356390, Validation Loss = 0.769387305
# Epoch: 403, Training Loss = 0.853275299, Validation Loss = 0.756064296
# Epoch: 404, Training Loss = 0.860989749, Validation Loss = 0.759393394
# Epoch: 405, Training Loss = 0.860060990, Validation Loss = 0.766704679
# Epoch: 406, Training Loss = 0.856709123, Validation Loss = 0.759391904
# Epoch: 407, Training Loss = 0.860905588, Validation Loss = 0.761798024
# Epoch: 408, Training Loss = 0.862574100, Validation Loss = 0.757630110
# Epoch: 409, Training Loss = 0.856126726, Validation Loss = 0.764868736
# Epoch: 410, Training Loss = 0.860351801, Validation Loss = 0.756457865
# Epoch: 411, Training Loss = 0.862584829, Validation Loss = 0.758976936
# Epoch: 412, Training Loss = 0.858144343, Validation Loss = 0.762244225
# Epoch: 413, Training Loss = 0.857132077, Validation Loss = 0.757919431
# Epoch: 414, Training Loss = 0.859755695, Validation Loss = 0.750053644
# Epoch: 415, Training Loss = 0.857754111, Validation Loss = 0.744981170
# Epoch: 416, Training Loss = 0.859979749, Validation Loss = 0.757213771
# Epoch: 417, Training Loss = 0.861073494, Validation Loss = 0.757929325
# Epoch: 418, Training Loss = 0.857396364, Validation Loss = 0.763834655
# Epoch: 419, Training Loss = 0.861678481, Validation Loss = 0.763112128
# Epoch: 420, Training Loss = 0.860005081, Validation Loss = 0.754468143
# Epoch: 421, Training Loss = 0.859213591, Validation Loss = 0.768313229
# Epoch: 422, Training Loss = 0.858283103, Validation Loss = 0.752472162
# Epoch: 423, Training Loss = 0.861040056, Validation Loss = 0.761226118
# Epoch: 424, Training Loss = 0.856613576, Validation Loss = 0.765990794
# Epoch: 425, Training Loss = 0.856559813, Validation Loss = 0.751110137
# Epoch: 426, Training Loss = 0.856390595, Validation Loss = 0.754070699
# Epoch: 427, Training Loss = 0.857833803, Validation Loss = 0.751910746
# Epoch: 428, Training Loss = 0.859211445, Validation Loss = 0.765011430
# Epoch: 429, Training Loss = 0.864077568, Validation Loss = 0.760921538
# Epoch: 430, Training Loss = 0.858205676, Validation Loss = 0.751168370
# Epoch: 431, Training Loss = 0.855453551, Validation Loss = 0.758129597
# Epoch: 432, Training Loss = 0.860454738, Validation Loss = 0.767100573
# Epoch: 433, Training Loss = 0.859174371, Validation Loss = 0.740815997
# Epoch: 434, Training Loss = 0.856384575, Validation Loss = 0.762875021
# Epoch: 435, Training Loss = 0.857313693, Validation Loss = 0.763384223
# Epoch: 436, Training Loss = 0.859760821, Validation Loss = 0.761128187
# Epoch: 437, Training Loss = 0.857002199, Validation Loss = 0.753423631
# Epoch: 438, Training Loss = 0.862487555, Validation Loss = 0.769611418
# Epoch: 439, Training Loss = 0.859492660, Validation Loss = 0.754130006
# Epoch: 440, Training Loss = 0.856004894, Validation Loss = 0.758960187
# Epoch: 441, Training Loss = 0.858478367, Validation Loss = 0.758755565
# Epoch: 442, Training Loss = 0.860148668, Validation Loss = 0.770103455
# Epoch: 443, Training Loss = 0.853815377, Validation Loss = 0.758907676
# Epoch: 444, Training Loss = 0.859920561, Validation Loss = 0.753912508
# Epoch: 445, Training Loss = 0.857568860, Validation Loss = 0.760761440
# Epoch: 446, Training Loss = 0.858443975, Validation Loss = 0.780496597
# Epoch: 447, Training Loss = 0.860811770, Validation Loss = 0.752815723
# Epoch: 448, Training Loss = 0.858342111, Validation Loss = 0.770113409
# Epoch: 449, Training Loss = 0.859017730, Validation Loss = 0.760949731
# Epoch: 450, Training Loss = 0.856469989, Validation Loss = 0.759078979
# Epoch: 451, Training Loss = 0.855243266, Validation Loss = 0.763130426
# Epoch: 452, Training Loss = 0.858299613, Validation Loss = 0.752992094
# Epoch: 453, Training Loss = 0.856132507, Validation Loss = 0.763112009
# Epoch: 454, Training Loss = 0.857996881, Validation Loss = 0.749071598
# Epoch: 455, Training Loss = 0.858267725, Validation Loss = 0.752683759
# Epoch: 456, Training Loss = 0.858865798, Validation Loss = 0.760668159
# Epoch: 457, Training Loss = 0.855417073, Validation Loss = 0.760559618
# Epoch: 458, Training Loss = 0.861907423, Validation Loss = 0.754607856
# Epoch: 459, Training Loss = 0.857029915, Validation Loss = 0.758334875
# Epoch: 460, Training Loss = 0.855821848, Validation Loss = 0.782854497
# Epoch: 461, Training Loss = 0.859512866, Validation Loss = 0.752806902
# Epoch: 462, Training Loss = 0.857256889, Validation Loss = 0.772537529
# Epoch: 463, Training Loss = 0.857882619, Validation Loss = 0.766204774
# Epoch: 464, Training Loss = 0.855310798, Validation Loss = 0.755147040
# Epoch: 465, Training Loss = 0.855365574, Validation Loss = 0.755277693
# Epoch: 466, Training Loss = 0.854386508, Validation Loss = 0.755142689
# Epoch: 467, Training Loss = 0.860049725, Validation Loss = 0.747610092
# Epoch: 468, Training Loss = 0.859194338, Validation Loss = 0.758640051
# Epoch: 469, Training Loss = 0.858843148, Validation Loss = 0.750300705
# Epoch: 470, Training Loss = 0.855053186, Validation Loss = 0.766933680
# Epoch: 471, Training Loss = 0.857198358, Validation Loss = 0.763823926
# Epoch: 472, Training Loss = 0.851837754, Validation Loss = 0.749210775
# Epoch: 473, Training Loss = 0.854801476, Validation Loss = 0.760160089
# Epoch: 474, Training Loss = 0.858909845, Validation Loss = 0.759368539
# Epoch: 475, Training Loss = 0.862570405, Validation Loss = 0.759402156
# Epoch: 476, Training Loss = 0.855433464, Validation Loss = 0.757272482
# Epoch: 477, Training Loss = 0.853731990, Validation Loss = 0.751501620
# Epoch: 478, Training Loss = 0.858782351, Validation Loss = 0.753118277
# Epoch: 479, Training Loss = 0.856688738, Validation Loss = 0.755416274
# Epoch: 480, Training Loss = 0.858873725, Validation Loss = 0.760869980
# Epoch: 481, Training Loss = 0.854101181, Validation Loss = 0.753409147
# Epoch: 482, Training Loss = 0.854350626, Validation Loss = 0.756762922
# Epoch: 483, Training Loss = 0.857278883, Validation Loss = 0.764810145
# Epoch: 484, Training Loss = 0.858152628, Validation Loss = 0.753130317
# Epoch: 485, Training Loss = 0.856032312, Validation Loss = 0.771867335
# Epoch: 486, Training Loss = 0.851745605, Validation Loss = 0.760190964
# Epoch: 487, Training Loss = 0.858841717, Validation Loss = 0.760194957
# Epoch: 488, Training Loss = 0.856544375, Validation Loss = 0.763978779
# Epoch: 489, Training Loss = 0.857157409, Validation Loss = 0.753488302
# Epoch: 490, Training Loss = 0.857007861, Validation Loss = 0.757488251
# Epoch: 491, Training Loss = 0.858462453, Validation Loss = 0.747526586
# Epoch: 492, Training Loss = 0.855509698, Validation Loss = 0.751153588
# Epoch: 493, Training Loss = 0.854428053, Validation Loss = 0.759144902
# Epoch: 494, Training Loss = 0.860662580, Validation Loss = 0.773352981
# Epoch: 495, Training Loss = 0.859054863, Validation Loss = 0.758628190
# Epoch: 496, Training Loss = 0.857427776, Validation Loss = 0.759757280
# Epoch: 497, Training Loss = 0.857571900, Validation Loss = 0.758986294
# Epoch: 498, Training Loss = 0.854877651, Validation Loss = 0.759962916
# Epoch: 499, Training Loss = 0.854622304, Validation Loss = 0.756302118
# Epoch: 500, Training Loss = 0.855269909, Validation Loss = 0.755322218

# %%
# 학습 및 검증 손실 시각화
plt.figure(figsize=(10, 5))
plt.plot(train_loss_list[20:], label='Training Loss')
plt.plot(validation_loss_list[20:], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Curve')
plt.legend()
plt.show()

# %% [markdown]
# ### Test

# %%
test_X_tensor = torch.tensor(test_X_data, dtype=torch.float32)

# TensorDataset과 DataLoader를 사용하여 배치 생성
dataset = TensorDataset(test_X_tensor)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, drop_last=False)

# %%
def evaluate_and_save(dataloader, model, file_path):
    model.eval()  # 모델을 평가 모드로 설정
    predictions = []

    with torch.no_grad():  # 기울기 계산 비활성화
        for X, in dataloader:  # 데이터 로더에서 데이터 배치를 반복
            X = X.to(device)  # 데이터를 적절한 디바이스로 이동 (CPU 또는 GPU)
            output = model(X)  # 모델로부터 예측 수행
            predictions.extend(np.round(output.cpu().numpy()).astype(int))  # 예측값을 리스트에 저장

    # 예측 결과를 DataFrame으로 변환
    predicted_df = pd.DataFrame(predictions, index=test_Y_data_df.index, columns=['Prediction'])
    # 결과를 CSV 파일로 저장
    predicted_df.to_csv(file_path)
    return predicted_df

# %%
# 함수 호출
file_path = "./Prediction/MLP_Performance.csv"
y_pred = evaluate_and_save(dataloader, model, file_path)

# %% [markdown]
# ### 정확도

# %%
# WRMSE 함수 정의
def WRMSE(predictions, answers):
    sum_answer = answers.sum().item()  # DataFrame에서 직접 합 계산
    if sum_answer == 0:
        return torch.sqrt(torch.tensor(0.001, dtype=torch.float))
    weights = answers / sum_answer  # 각 값에 대해 가중치 계산
    loss = (weights * (predictions - answers).pow(2)).sum().item()  # 가중치 적용한 오차 제곱합
    return torch.sqrt(torch.tensor(loss, dtype=torch.float))

# %%
test_rmse = np.sqrt(mean_squared_error(test_Y_data, y_pred))

print(f'Test RMSE: {test_rmse}')

# 텐서 변환
test_targets_tensor = torch.tensor(test_Y_data_df['Kp'].values, dtype=torch.float32)
test_predictions_tensor = torch.tensor(y_pred['Prediction'].values, dtype=torch.float32)

# WRMSE 계산
wrmse_value = WRMSE(test_predictions_tensor, test_targets_tensor)
print(f'Test WRMSE: {wrmse_value.item()}')

# R²
RS_r2 = r2_score(test_Y_data, y_pred)
print(f'Test R²: {RS_r2}')

# MAE
RS_mae = mean_absolute_error(test_Y_data, y_pred)
print(f'Test MAE: {RS_mae}')
# Out:
# Test RMSE: 0.7807618337853679
# Test WRMSE: 0.7369709014892578
# Test R²: 0.5349925779175512
# Test MAE: 0.5417808219178082

# %%
test_rmse = np.sqrt(mean_squared_error(test_Y_data, y_pred))

print(f'Test RMSE: {test_rmse}')

# 텐서 변환
test_targets_tensor = torch.tensor(test_Y_data_df['Kp'].values, dtype=torch.float32)
test_predictions_tensor = torch.tensor(y_pred['Prediction'].values, dtype=torch.float32)

# WRMSE 계산
wrmse_value = WRMSE(test_predictions_tensor, test_targets_tensor)
print(f'Test WRMSE: {wrmse_value.item()}')

# R²
RS_r2 = r2_score(test_Y_data, y_pred)
print(f'Test R²: {RS_r2}')

# MAE
RS_mae = mean_absolute_error(test_Y_data, y_pred)
print(f'Test MAE: {RS_mae}')
# Out:
# Test RMSE: 0.7807618337853679
# Test WRMSE: 0.7369709014892578
# Test R²: 0.5349925779175512
# Test MAE: 0.5417808219178082

# %% [markdown]
# ### 시각화

# %%
plt.figure(figsize=(15, 7))
plt.plot(test_Y_data_df, label='Test Data')
plt.plot(y_pred, label='Test Predictions', color='red')
plt.title('ARIMAX Model Predictions')
plt.xlabel('Date')
plt.ylabel('Kp Index')
plt.legend()
plt.show()

# %%
print(type(y_pred))
y_pred.to_csv('./MLP_Prediction/MLP_median.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
def print_model_summary(model):
    """
    Prints the summary of a PyTorch nn.Module model, including its layers and parameters.

    Parameters:
    model (nn.Module): The PyTorch model to summarize.

    """
    for name, layer in model.named_children():
        print(f"Layer: {name}")
        print(f"Type: {type(layer)}")
        for param_name, param in layer.named_parameters():
            print(f"    Parameter: {param_name}, Shape: {param.shape}")

# %%
print_model_summary(model)
# Out:
# Layer: linear1
# Type: <class 'torch.nn.modules.linear.Linear'>
#     Parameter: weight, Shape: torch.Size([800, 35])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: batch_norm1
# Type: <class 'torch.nn.modules.batchnorm.BatchNorm1d'>
#     Parameter: weight, Shape: torch.Size([800])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: dropout1
# Type: <class 'torch.nn.modules.dropout.Dropout'>
# Layer: linear2
# Type: <class 'torch.nn.modules.linear.Linear'>
#     Parameter: weight, Shape: torch.Size([800, 800])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: batch_norm2
# Type: <class 'torch.nn.modules.batchnorm.BatchNorm1d'>
#     Parameter: weight, Shape: torch.Size([800])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: dropout2
# Type: <class 'torch.nn.modules.dropout.Dropout'>
# Layer: linear3
# Type: <class 'torch.nn.modules.linear.Linear'>
#     Parameter: weight, Shape: torch.Size([800, 800])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: batch_norm3
# Type: <class 'torch.nn.modules.batchnorm.BatchNorm1d'>
#     Parameter: weight, Shape: torch.Size([800])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: dropout3
# Type: <class 'torch.nn.modules.dropout.Dropout'>
# Layer: linear4
# Type: <class 'torch.nn.modules.linear.Linear'>
#     Parameter: weight, Shape: torch.Size([800, 800])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: batch_norm4
# Type: <class 'torch.nn.modules.batchnorm.BatchNorm1d'>
#     Parameter: weight, Shape: torch.Size([800])
#     Parameter: bias, Shape: torch.Size([800])
# Layer: dropout4
# Type: <class 'torch.nn.modules.dropout.Dropout'>
# Layer: linear5
# Type: <class 'torch.nn.modules.linear.Linear'>
#     Parameter: weight, Shape: torch.Size([1, 800])
#     Parameter: bias, Shape: torch.Size([1])
# Layer: relu
# Type: <class 'torch.nn.modules.activation.ReLU'>
